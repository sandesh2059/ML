# %% [markdown]
# <a href="https://colab.research.google.com/github/sandesh2059/ML/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PANDAS
# Data preprocessing in Machine Learning using Pandas
# Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# Pandas is an open source Python package that is most widely used for data science/data analysis
# and machine learning tasks.it is built on the top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data order to transform them into a standard and normalized format.
#
#   Preprocessing involves the following aspects:
#     *missing values
#     *data standardization
#     *data normalization
#     *data mining

# %%
import pandas as pd

data= {
    "cars": ["bmw", "honda", "suzuki", "byd"],
    "models": ["2007", "2008", "2006", "2009"],
    "passen": ["4", "6", "6", "5"]

}

# %%
# convert the data dictionary to dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2006      6
# 3     byd   2009      5

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/5thsemdata/car_data.csv")

# %%
df = pd.read_csv("/content/car_data.csv")
df
# Out:
#    Unnamed: 0    cars  models  passen
# 0           0     bmw    2007       4
# 1           1   honda    2008       6
# 2           2  suzuki    2006       6
# 3           3     byd    2009       5

# %%
# create a dataframe with two fratures calories and duration
data= {
    "calories": ["420", "500", "390", "450"],
    "duration": ["50", "60", "45", "48"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45
# 3      450       48
